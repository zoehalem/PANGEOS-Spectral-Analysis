# %% [markdown]
# # Spectral Unmixing Notebook
# ## Adapted from Ochoa et al. (2025) for SVC data
# Follow installation instructions step in README.md (https://github.com/emit-sds/SpectralUnmixing.jl) prior to running

# %%
using Pkg
Pkg.activate("C:/Users/zhalem/Documents/spectralunmixing")  
Pkg.instantiate()
# Out:
#   Activating project at `C:\Users\zhalem\Documents\spectralunmixing`

# %%
using Plots
using SpectralUnmixing
using Statistics
using CSV
using DataFrames
using Pkg
Pkg.instantiate()    # installs any missing dependencies recorded for this environment
Pkg.add("Plots")     # explicitly adds Plots if it’s not in the Project.toml
Pkg.add("Statistics")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\zhalem\Documents\spectralunmixing\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\zhalem\Documents\spectralunmixing\Manifest.toml`
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\zhalem\Documents\spectralunmixing\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\zhalem\Documents\spectralunmixing\Manifest.toml`

# %% [markdown]
# # Spectral Library Preparation
#
# Start by loading up a spectral library (Ochoa et al. [10.21232/QijXnpFt](https://doi.org/10.21232/QijXnpFt)), filtering it down to the desired classes, interpolating the spectra to the relevant wavelengths, and then removing undesired wavelength regions. By default the ignored regions correspond to atmospheric absorption regions. Here we split the library into two classes, soil and vegetation.

# %%
open("fake_refle.hdr", "w") do io
    wavelengths = 360:2500
    println(io, "ENVI")
    println(io, "description = {Fake SVC header for unmixing}")
    println(io, "samples = 1")
    println(io, "lines = 1")
    println(io, "bands = $(length(wavelengths))")
    println(io, "data type = 4")
    println(io, "interleave = bsq")
    println(io, "byte order = 0")
    println(io, "wavelength units = Nanometers")
    println(io, "wavelength = {" * join(wavelengths, ", ") * "}")
end

# %%
# two endmember classes (column name 'level_1') are soil and leaf
endmember_library = SpectralLibrary("endmember_svc_data_pangeos.csv", "level_1", 10, 0, ["soil","leaf"]);
load_data!(endmember_library);
filter_by_class!(endmember_library);

# 10, 0 refers to number of spectral bands to skip between samples or a window size for smoothing
# make sure the 'fake_refle' file is downloaded in the correct folder prior to running
# 'fake_refle' is an envi format file with all wavelengths

refl_file_wl = read_envi_wavelengths("fake_refle");
interpolate_library_to_new_wavelengths!(endmember_library, refl_file_wl);

# remove water band regions with lots of noise
# fill the ignored regions with NaNs to improve visualization of the endmember spectra.
remove_wavelength_region_inplace!(endmember_library, true);

plot_endmembers_individually(endmember_library)
plot!(margin=5Plots.mm)
# Out:
# [ Info: Ignoring wavelength regions: Any[[0, 440], [1310, 1490], [1770, 2050], [2440, 2880]]

# %%
# Copies the library spectra and wavelengths so we don't modify the original directly
# Clean the library wavelength axis (remove NaNs, duplicates, sorts) 
lib_wl = copy(endmember_library.wavelengths)
lib_spec = copy(endmember_library.spectra)

# Remove NaNs in wavelengths
valid_idx = findall(!isnan, lib_wl)
lib_wl = lib_wl[valid_idx]
lib_spec = lib_spec[:, valid_idx]

# update the library
endmember_library.wavelengths = lib_wl
endmember_library.spectra = lib_spec;

# %%
# Loads in measured spectra (mixed spectra)
mixed_file = "mixed_rows_test.csv"
df_mixed = CSV.read(mixed_file, DataFrame)

# Extract spectrum names (first column = fname)
mixed_names = df_mixed.fname

# Extract reflectances (remaining columns), keep NaNs for masked bands
mixed_rfl = Matrix{Float64}(coalesce.(df_mixed[:, Not(:fname)], NaN));

# %%
# Attempt to infer measurement wavelength axis from column names when appropriate:
#retrieve column headers
col_names = names(df_mixed)
first_col_is_name = eltype(df_mixed[:,1]) <: AbstractString

# if statement to check that the strings in columns 2:end are purely numbers, not letters
# r"..." = Julia regular expression (regex)
# ^ = start of string
# \d+ = one or more digits (0-9)
# $ = end of string
if first_col_is_name && all(x -> occursin(r"^\d+$", x), string.(col_names[2:end]))
    my_wavelengths = Float64.(parse.(Float64, string.(col_names[2:end])))
else
    # Fallback: assume 360..2500 step 1 
    my_wavelengths = Float64.(360:1:2500)
end

# sanity checks to make sure matrix size and wavelengths match
@show size(mixed_rfl)
@show length(my_wavelengths)
# Out:
# size(mixed_rfl) = (371, 2141)
# length(my_wavelengths) = 2141
# 2141

# %%
# 3) Interpolate / align endmember library to measurement wavelengths
interpolate_library_to_new_wavelengths!(endmember_library, my_wavelengths)

# Remove ignored/bad wavelength regions entirely (faster for computation)
# pass false to remove them instead of filling with NaNs
remove_wavelength_region_inplace!(endmember_library, true)

# Sanity checks to ensure lengths match
@show length(endmember_library.wavelengths)
@show sum(endmember_library.good_bands)
@show size(endmember_library.spectra)
# Out:
# length(endmember_library.wavelengths) = 2141
# sum(endmember_library.good_bands) = 1537
# size(endmember_library.spectra) = (106, 2141)
# (106, 2141)

# %% [markdown]
# # A Single SMA Unmixing Case
# Unmixing is done using a Monte Carlo (MC) method where endmembers are chosen at random to construct the unmixing matrices using two main approaches: spectral mixture analysis (SMA) and multiple-endmember spectral mixture analysis (MESMA).
#
# There are a few options that must be set for unmixing, including the number of MC loops, the unmixing mode (`"sma-best"` here corresponds to SMA and using the lowest cost solution from MC), number of endmembers, the normalization mode, and optimization mode. After the prep steps, the single function `unmix_pixel()` performs the MC matrix inversions and outputs the unmixing results.
#
# See Ochoa et al. (in preparation) for more info on different unmixing techniques and options.

# %%
#4) Prepare options and combination indices for unmixing
n_mc = 25
mode = "sma-best" 
num_endmembers = [30]          # vector expected by prepare_options
normalization = "none"   # normalization = 'none' for no brightness normalization (or "brightness" if you want to normalize by brightness, but does not make sense in this case because there is no canopy shading like with satellite data)
optimization = "bvls"
max_combinations = 1000
combination_type = "class-even"
# Out:
# "class-even"

# %%
# Prepare combination/class indices and options (these helper functions are from SpectralUnmixing)
class_idx = prepare_combinations(endmember_library, combination_type)
options = prepare_options(endmember_library, combination_type, num_endmembers, class_idx)

# Prepare storage for CSV export
spectrum_name_out = String[]
brightness_out    = Float64[]
soil_frac_out     = Float64[]
leaf_frac_out     = Float64[]

# 5) Unmix each measured spectrum using the prepared library
println("Starting unmixing for $(size(mixed_rfl,1)) spectra...")

n_spectra = size(mixed_rfl,1)
cfr_all = Vector{Any}(undef, n_spectra)  # store cfr for each spectrum
mr_all  = Vector{Vector{Float64}}(undef, n_spectra)
mv_all  = Vector{Vector{Float64}}(undef, n_spectra)
cfv_all = Vector{Vector{Float64}}(undef, n_spectra)

for i in 1:size(mixed_rfl,1)
    # Mask measured spectrum to only the library 'good' bands
    # If library.good_bands is boolean mask, use it directly; otherwise assume it is indices
    gb = endmember_library.good_bands
    good_mask = endmember_library.good_bands
    spectrum_vec = vec(mixed_rfl[i, good_mask])

    # Run unmixing
    mr, mv, cfr, cfv = unmix_pixel(
        endmember_library,
        spectrum_vec,
        nothing,          # no ancillary (e.g. mask) provided
        class_idx,
        options,
        mode,
        n_mc,
        num_endmembers,
        normalization,
        optimization,
        max_combinations,
        combination_type
    )

    #store cfr for this spectrum
    cfr_all[i] = cfr
# Output: brightness appended as last element in mr
    brightness = mr[end]
    println("Spectrum $(mixed_names[i]): Brightness: $(round(brightness*100, digits=2)) %")
    for (class, fraction) in zip(endmember_library.class_valid_keys, mr[1:end-1])
        println("    $class fraction: $(round(fraction*100, digits=2)) %")     
    end

    push!(spectrum_name_out, mixed_names[i])
    push!(brightness_out, brightness)

    fractions = Dict(
        class => frac for (class, frac) in
        zip(endmember_library.class_valid_keys, mr[1:end-1])
    )

    push!(soil_frac_out, fractions["soil"])
    push!(leaf_frac_out, fractions["leaf"])

end

results_df = DataFrame(
    spectrum_name = spectrum_name_out,
    brightness    = brightness_out,
    soil_fraction = soil_frac_out,
    leaf_fraction = leaf_frac_out
)

CSV.write("unmixing_results.csv", results_df)
# Out:
# Starting unmixing for 371 spectra...
# Spectrum 14deg_plot_11_01_0000: Brightness: 79.25 %
#     soil fraction: 38.31 %
#     leaf fraction: 61.69 %
# Spectrum 14deg_plot_11_01_0001: Brightness: 72.58 %
#     soil fraction: 27.78 %
#     leaf fraction: 72.22 %
# Spectrum 14deg_plot_11_01_0002: Brightness: 79.84 %
#     soil fraction: 22.8 %
#     leaf fraction: 77.2 %
# Spectrum 14deg_plot_11_01_0003: Brightness: 74.22 %
#     soil fraction: 22.49 %
#     leaf fraction: 77.51 %
# Spectrum 14deg_plot_11_01_0004: Brightness: 69.75 %
#     soil fraction: 9.73 %
#     leaf fraction: 90.27 %
# Spectrum 14deg_plot_11_02_0000: Brightness: 68.39 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_02_0001: Brightness: 74.78 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_02_0002: Brightness: 69.05 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_02_0003: Brightness: 56.8 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_03_0000 (2): Brightness: 58.93 %
#     soil fraction: 10.05 %
#     leaf fraction: 89.95 %
# Spectrum 14deg_plot_11_03_0000: Brightness: 101.58 %
#     soil fraction: 35.01 %
#     leaf fraction: 64.99 %
# Spectrum 14deg_plot_11_03_0001 (2): Brightness: 52.41 %
#     soil fraction: 5.69 %
#     leaf fraction: 94.31 %
# Spectrum 14deg_plot_11_03_0001: Brightness: 89.83 %
#     soil fraction: 39.74 %
#     leaf fraction: 60.26 %
# Spectrum 14deg_plot_11_03_0002 (2): Brightness: 66.17 %
#     soil fraction: 6.5 %
#     leaf fraction: 93.5 %
# Spectrum 14deg_plot_11_03_0002: Brightness: 77.97 %
#     soil fraction: 25.71 %
#     leaf fraction: 74.29 %
# Spectrum 14deg_plot_11_03_0003 (2): Brightness: 54.8 %
#     soil fraction: 14.65 %
#     leaf fraction: 85.35 %
# Spectrum 14deg_plot_11_03_0003: Brightness: 92.57 %
#     soil fraction: 27.93 %
#     leaf fraction: 72.07 %
# Spectrum 14deg_plot_11_03_0004 (2): Brightness: 68.15 %
#     soil fraction: 25.68 %
#     leaf fraction: 74.32 %
# Spectrum 14deg_plot_11_03_0004: Brightness: 81.88 %
#     soil fraction: 40.08 %
#     leaf fraction: 59.92 %
# Spectrum 14deg_plot_11_04_0000: Brightness: 106.19 %
#     soil fraction: 39.58 %
#     leaf fraction: 60.42 %
# Spectrum 14deg_plot_11_04_0001: Brightness: 107.22 %
#     soil fraction: 40.02 %
#     leaf fraction: 59.98 %
# Spectrum 14deg_plot_11_04_0002: Brightness: 94.67 %
#     soil fraction: 19.32 %
#     leaf fraction: 80.68 %
# Spectrum 14deg_plot_11_04_0003: Brightness: 87.36 %
#     soil fraction: 46.07 %
#     leaf fraction: 53.93 %
# Spectrum 14deg_plot_11_04_0004: Brightness: 97.18 %
#     soil fraction: 37.95 %
#     leaf fraction: 62.05 %
# Spectrum 14deg_plot_11_05_0000: Brightness: 61.74 %
#     soil fraction: 10.18 %
#     leaf fraction: 89.82 %
# Spectrum 14deg_plot_11_05_0001: Brightness: 85.54 %
#     soil fraction: 28.4 %
#     leaf fraction: 71.6 %
# Spectrum 14deg_plot_11_05_0002: Brightness: 58.99 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_05_0003: Brightness: 43.71 %
#     soil fraction: 16.23 %
#     leaf fraction: 83.77 %
# Spectrum 14deg_plot_11_05_0004: Brightness: 46.06 %
#     soil fraction: 19.39 %
#     leaf fraction: 80.61 %
# Spectrum 14deg_plot_11_06_0000: Brightness: 65.04 %
#     soil fraction: 21.87 %
#     leaf fraction: 78.13 %
# Spectrum 14deg_plot_11_06_0001: Brightness: 46.43 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_06_0002: Brightness: 40.0 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_06_0003: Brightness: 46.84 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_06_0004: Brightness: 43.97 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_07_0000: Brightness: 61.54 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_07_0001: Brightness: 50.12 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_07_0002: Brightness: 49.71 %
#     soil fraction: 5.48 %
#     leaf fraction: 94.52 %
# Spectrum 14deg_plot_11_07_0003: Brightness: 55.44 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_07_0004: Brightness: 54.31 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0000 (2): Brightness: 48.99 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0000: Brightness: 59.56 %
#     soil fraction: 24.87 %
#     leaf fraction: 75.13 %
# Spectrum 14deg_plot_11_08_0001 (2): Brightness: 49.04 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0001: Brightness: 78.09 %
#     soil fraction: 14.0 %
#     leaf fraction: 86.0 %
# Spectrum 14deg_plot_11_08_0002 (2): Brightness: 49.87 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0002: Brightness: 71.52 %
#     soil fraction: 19.94 %
#     leaf fraction: 80.06 %
# Spectrum 14deg_plot_11_08_0003 (2): Brightness: 50.14 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0003: Brightness: 64.45 %
#     soil fraction: 8.12 %
#     leaf fraction: 91.88 %
# Spectrum 14deg_plot_11_08_0004 (2): Brightness: 44.29 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_08_0004: Brightness: 69.27 %
#     soil fraction: 10.58 %
#     leaf fraction: 89.42 %
# Spectrum 14deg_plot_11_09_0000: Brightness: 45.54 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_09_0001: Brightness: 50.93 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_09_0002: Brightness: 39.27 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_09_0003: Brightness: 40.35 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_09_0004: Brightness: 44.07 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0000: Brightness: 67.52 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0001: Brightness: 78.31 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0002: Brightness: 152.85 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0003: Brightness: 133.26 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0004: Brightness: 157.67 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0005: Brightness: 134.21 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0006: Brightness: 55.33 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_11_10_0007: Brightness: 46.84 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_07_0000: Brightness: 56.32 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_07_0001: Brightness: 58.12 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_07_0002: Brightness: 66.85 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_07_0003: Brightness: 53.2 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_07_0004: Brightness: 66.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_12_08_0000: Brightness: 80.23 %
#     soil fraction: 28.02 %
#     leaf fraction: 71.98 %
# Spectrum 14deg_plot_12_08_0001: Brightness: 67.89 %
#     soil fraction: 59.91 %
#     leaf fraction: 40.09 %
# Spectrum 14deg_plot_12_08_0002: Brightness: 71.85 %
#     soil fraction: 60.5 %
#     leaf fraction: 39.5 %
# Spectrum 14deg_plot_12_08_0003: Brightness: 69.55 %
#     soil fraction: 36.15 %
#     leaf fraction: 63.85 %
# Spectrum 14deg_plot_12_08_0004: Brightness: 84.73 %
#     soil fraction: 71.25 %
#     leaf fraction: 28.75 %
# Spectrum 14deg_plot_12_10_0000: Brightness: 74.18 %
#     soil fraction: 43.72 %
#     leaf fraction: 56.28 %
# Spectrum 14deg_plot_12_10_0001: Brightness: 57.58 %
#     soil fraction: 17.25 %
#     leaf fraction: 82.75 %
# Spectrum 14deg_plot_12_10_0002: Brightness: 72.75 %
#     soil fraction: 19.09 %
#     leaf fraction: 80.91 %
# Spectrum 14deg_plot_12_10_0003: Brightness: 76.95 %
#     soil fraction: 32.5 %
#     leaf fraction: 67.5 %
# Spectrum 14deg_plot_12_10_0004: Brightness: 58.57 %
#     soil fraction: 12.46 %
#     leaf fraction: 87.54 %
# Spectrum 14deg_plot_13_04_0000: Brightness: 60.96 %
#     soil fraction: 29.65 %
#     leaf fraction: 70.35 %
# Spectrum 14deg_plot_13_04_0001: Brightness: 66.16 %
#     soil fraction: 36.11 %
#     leaf fraction: 63.89 %
# Spectrum 14deg_plot_13_04_0002: Brightness: 58.1 %
#     soil fraction: 0.76 %
#     leaf fraction: 99.24 %
# Spectrum 14deg_plot_13_04_0003: Brightness: 59.02 %
#     soil fraction: 18.77 %
#     leaf fraction: 81.23 %
# Spectrum 14deg_plot_13_04_0004: Brightness: 68.46 %
#     soil fraction: 15.54 %
#     leaf fraction: 84.46 %
# Spectrum 14deg_plot_13_05_0000: Brightness: 101.49 %
#     soil fraction: 82.6 %
#     leaf fraction: 17.4 %
# Spectrum 14deg_plot_13_05_0001: Brightness: 96.49 %
#     soil fraction: 95.87 %
#     leaf fraction: 4.13 %
# Spectrum 14deg_plot_13_05_0002: Brightness: 105.49 %
#     soil fraction: 76.72 %
#     leaf fraction: 23.28 %
# Spectrum 14deg_plot_13_05_0003: Brightness: 96.97 %
#     soil fraction: 86.41 %
#     leaf fraction: 13.59 %
# Spectrum 14deg_plot_13_05_0004: Brightness: 82.98 %
#     soil fraction: 69.57 %
#     leaf fraction: 30.43 %
# Spectrum 14deg_plot_13_10_0000: Brightness: 111.88 %
#     soil fraction: 24.16 %
#     leaf fraction: 75.84 %
# Spectrum 14deg_plot_13_10_0001: Brightness: 113.24 %
#     soil fraction: 60.44 %
#     leaf fraction: 39.56 %
# Spectrum 14deg_plot_13_10_0002: Brightness: 144.23 %
#     soil fraction: 31.44 %
#     leaf fraction: 68.56 %
# Spectrum 14deg_plot_13_10_0003: Brightness: 114.5 %
#     soil fraction: 16.35 %
#     leaf fraction: 83.65 %
# Spectrum 14deg_plot_13_10_0004: Brightness: 127.9 %
#     soil fraction: 52.55 %
#     leaf fraction: 47.45 %
# Spectrum 14deg_plot_14_01_0000: Brightness: 68.37 %
#     soil fraction: 33.6 %
#     leaf fraction: 66.4 %
# Spectrum 14deg_plot_14_01_0001: Brightness: 75.15 %
#     soil fraction: 32.39 %
#     leaf fraction: 67.61 %
# Spectrum 14deg_plot_14_01_0002: Brightness: 81.02 %
#     soil fraction: 28.41 %
#     leaf fraction: 71.59 %
# Spectrum 14deg_plot_14_01_0003: Brightness: 79.14 %
#     soil fraction: 31.53 %
#     leaf fraction: 68.47 %
# Spectrum 14deg_plot_14_01_0004: Brightness: 75.23 %
#     soil fraction: 48.18 %
#     leaf fraction: 51.82 %
# Spectrum 14deg_plot_14_02_0000 (2): Brightness: 72.66 %
#     soil fraction: 35.66 %
#     leaf fraction: 64.34 %
# Spectrum 14deg_plot_14_02_0000: Brightness: 67.19 %
#     soil fraction: 63.91 %
#     leaf fraction: 36.09 %
# Spectrum 14deg_plot_14_02_0001 (2): Brightness: 55.25 %
#     soil fraction: 20.57 %
#     leaf fraction: 79.43 %
# Spectrum 14deg_plot_14_02_0001: Brightness: 72.15 %
#     soil fraction: 39.19 %
#     leaf fraction: 60.81 %
# Spectrum 14deg_plot_14_02_0002 (2): Brightness: 74.4 %
#     soil fraction: 39.56 %
#     leaf fraction: 60.44 %
# Spectrum 14deg_plot_14_02_0002: Brightness: 65.14 %
#     soil fraction: 65.68 %
#     leaf fraction: 34.32 %
# Spectrum 14deg_plot_14_02_0003 (2): Brightness: 60.86 %
#     soil fraction: 35.23 %
#     leaf fraction: 64.77 %
# Spectrum 14deg_plot_14_02_0003: Brightness: 75.75 %
#     soil fraction: 74.08 %
#     leaf fraction: 25.92 %
# Spectrum 14deg_plot_14_02_0004 (2): Brightness: 72.7 %
#     soil fraction: 38.37 %
#     leaf fraction: 61.63 %
# Spectrum 14deg_plot_14_02_0004: Brightness: 95.62 %
#     soil fraction: 62.35 %
#     leaf fraction: 37.65 %
# Spectrum 14deg_plot_14_02_0005 (2): Brightness: 62.16 %
#     soil fraction: 25.28 %
#     leaf fraction: 74.72 %
# Spectrum 14deg_plot_14_02_0005: Brightness: 72.07 %
#     soil fraction: 52.19 %
#     leaf fraction: 47.81 %
# Spectrum 14deg_plot_14_03_0000: Brightness: 83.23 %
#     soil fraction: 54.39 %
#     leaf fraction: 45.61 %
# Spectrum 14deg_plot_14_03_0001: Brightness: 92.84 %
#     soil fraction: 38.53 %
#     leaf fraction: 61.47 %
# Spectrum 14deg_plot_14_03_0002: Brightness: 87.34 %
#     soil fraction: 49.06 %
#     leaf fraction: 50.94 %
# Spectrum 14deg_plot_14_03_0003: Brightness: 82.99 %
#     soil fraction: 61.5 %
#     leaf fraction: 38.5 %
# Spectrum 14deg_plot_14_03_0004: Brightness: 89.44 %
#     soil fraction: 47.38 %
#     leaf fraction: 52.62 %
# Spectrum 14deg_plot_14_04_0000: Brightness: 73.86 %
#     soil fraction: 4.59 %
#     leaf fraction: 95.41 %
# Spectrum 14deg_plot_14_04_0001: Brightness: 93.51 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_14_04_0002: Brightness: 77.28 %
#     soil fraction: 16.95 %
#     leaf fraction: 83.05 %
# Spectrum 14deg_plot_14_04_0003: Brightness: 89.52 %
#     soil fraction: 13.34 %
#     leaf fraction: 86.66 %
# Spectrum 14deg_plot_14_04_0004: Brightness: 74.26 %
#     soil fraction: 20.15 %
#     leaf fraction: 79.85 %
# Spectrum 14deg_plot_14_05_0000 (2): Brightness: 82.1 %
#     soil fraction: 49.48 %
#     leaf fraction: 50.52 %
# Spectrum 14deg_plot_14_05_0000: Brightness: 97.0 %
#     soil fraction: 69.93 %
#     leaf fraction: 30.07 %
# Spectrum 14deg_plot_14_05_0001 (2): Brightness: 86.61 %
#     soil fraction: 40.0 %
#     leaf fraction: 60.0 %
# Spectrum 14deg_plot_14_05_0001: Brightness: 96.81 %
#     soil fraction: 63.39 %
#     leaf fraction: 36.61 %
# Spectrum 14deg_plot_14_05_0002 (2): Brightness: 77.22 %
#     soil fraction: 45.13 %
#     leaf fraction: 54.87 %
# Spectrum 14deg_plot_14_05_0002: Brightness: 96.82 %
#     soil fraction: 61.94 %
#     leaf fraction: 38.06 %
# Spectrum 14deg_plot_14_05_0003 (2): Brightness: 78.36 %
#     soil fraction: 42.45 %
#     leaf fraction: 57.55 %
# Spectrum 14deg_plot_14_05_0003: Brightness: 87.56 %
#     soil fraction: 60.53 %
#     leaf fraction: 39.47 %
# Spectrum 14deg_plot_14_05_0004 (2): Brightness: 77.86 %
#     soil fraction: 47.83 %
#     leaf fraction: 52.17 %
# Spectrum 14deg_plot_14_05_0004: Brightness: 92.04 %
#     soil fraction: 69.15 %
#     leaf fraction: 30.85 %
# Spectrum 14deg_plot_14_06_0000: Brightness: 72.92 %
#     soil fraction: 35.33 %
#     leaf fraction: 64.67 %
# Spectrum 14deg_plot_14_06_0001: Brightness: 79.09 %
#     soil fraction: 35.64 %
#     leaf fraction: 64.36 %
# Spectrum 14deg_plot_14_06_0002: Brightness: 65.51 %
#     soil fraction: 41.68 %
#     leaf fraction: 58.32 %
# Spectrum 14deg_plot_14_06_0003: Brightness: 83.4 %
#     soil fraction: 41.61 %
#     leaf fraction: 58.39 %
# Spectrum 14deg_plot_14_06_0004: Brightness: 105.03 %
#     soil fraction: 33.99 %
#     leaf fraction: 66.01 %
# Spectrum 14deg_plot_14_07_0000: Brightness: 136.77 %
#     soil fraction: 60.9 %
#     leaf fraction: 39.1 %
# Spectrum 14deg_plot_14_07_0001: Brightness: 107.12 %
#     soil fraction: 65.43 %
#     leaf fraction: 34.57 %
# Spectrum 14deg_plot_14_07_0002: Brightness: 104.25 %
#     soil fraction: 52.14 %
#     leaf fraction: 47.86 %
# Spectrum 14deg_plot_14_07_0003: Brightness: 93.87 %
#     soil fraction: 57.75 %
#     leaf fraction: 42.25 %
# Spectrum 14deg_plot_14_07_0004: Brightness: 114.09 %
#     soil fraction: 89.48 %
#     leaf fraction: 10.52 %
# Spectrum 14deg_plot_14_08_0000: Brightness: 106.92 %
#     soil fraction: 53.8 %
#     leaf fraction: 46.2 %
# Spectrum 14deg_plot_14_08_0001: Brightness: 93.52 %
#     soil fraction: 27.29 %
#     leaf fraction: 72.71 %
# Spectrum 14deg_plot_14_08_0002: Brightness: 107.34 %
#     soil fraction: 43.77 %
#     leaf fraction: 56.23 %
# Spectrum 14deg_plot_14_08_0003: Brightness: 81.56 %
#     soil fraction: 44.52 %
#     leaf fraction: 55.48 %
# Spectrum 14deg_plot_14_08_0004: Brightness: 95.75 %
#     soil fraction: 24.24 %
#     leaf fraction: 75.76 %
# Spectrum 14deg_plot_14_09_0000 (2): Brightness: 42.06 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_14_09_0000: Brightness: 130.78 %
#     soil fraction: 71.7 %
#     leaf fraction: 28.3 %
# Spectrum 14deg_plot_14_09_0001 (2): Brightness: 44.63 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_14_09_0001: Brightness: 143.73 %
#     soil fraction: 68.25 %
#     leaf fraction: 31.75 %
# Spectrum 14deg_plot_14_09_0002 (2): Brightness: 73.92 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_14_09_0002: Brightness: 136.07 %
#     soil fraction: 70.95 %
#     leaf fraction: 29.05 %
# Spectrum 14deg_plot_14_09_0003 (2): Brightness: 74.98 %
#     soil fraction: 1.39 %
#     leaf fraction: 98.61 %
# Spectrum 14deg_plot_14_09_0003: Brightness: 136.41 %
#     soil fraction: 53.29 %
#     leaf fraction: 46.71 %
# Spectrum 14deg_plot_14_09_0004 (2): Brightness: 91.87 %
#     soil fraction: 5.88 %
#     leaf fraction: 94.12 %
# Spectrum 14deg_plot_14_09_0004: Brightness: 86.78 %
#     soil fraction: 29.54 %
#     leaf fraction: 70.46 %
# Spectrum 14deg_plot_14_10_0000: Brightness: 98.77 %
#     soil fraction: 47.89 %
#     leaf fraction: 52.11 %
# Spectrum 14deg_plot_14_10_0001: Brightness: 103.19 %
#     soil fraction: 41.07 %
#     leaf fraction: 58.93 %
# Spectrum 14deg_plot_14_10_0002: Brightness: 101.82 %
#     soil fraction: 52.17 %
#     leaf fraction: 47.83 %
# Spectrum 14deg_plot_14_10_0003: Brightness: 68.95 %
#     soil fraction: 39.16 %
#     leaf fraction: 60.84 %
# Spectrum 14deg_plot_14_10_0004: Brightness: 85.35 %
#     soil fraction: 40.88 %
#     leaf fraction: 59.12 %
# Spectrum 14deg_plot_15_01_0000: Brightness: 77.59 %
#     soil fraction: 42.13 %
#     leaf fraction: 57.87 %
# Spectrum 14deg_plot_15_01_0001: Brightness: 93.72 %
#     soil fraction: 54.79 %
#     leaf fraction: 45.21 %
# Spectrum 14deg_plot_15_01_0002: Brightness: 97.58 %
#     soil fraction: 62.05 %
#     leaf fraction: 37.95 %
# Spectrum 14deg_plot_15_01_0003: Brightness: 88.79 %
#     soil fraction: 46.37 %
#     leaf fraction: 53.63 %
# Spectrum 14deg_plot_15_01_0004: Brightness: 78.52 %
#     soil fraction: 28.25 %
#     leaf fraction: 71.75 %
# Spectrum 14deg_plot_15_02_0000 (2): Brightness: 46.36 %
#     soil fraction: 25.58 %
#     leaf fraction: 74.42 %
# Spectrum 14deg_plot_15_02_0000: Brightness: 122.8 %
#     soil fraction: 63.42 %
#     leaf fraction: 36.58 %
# Spectrum 14deg_plot_15_02_0001 (2): Brightness: 104.38 %
#     soil fraction: 43.61 %
#     leaf fraction: 56.39 %
# Spectrum 14deg_plot_15_02_0001: Brightness: 66.79 %
#     soil fraction: 19.67 %
#     leaf fraction: 80.33 %
# Spectrum 14deg_plot_15_02_0002 (2): Brightness: 109.63 %
#     soil fraction: 62.09 %
#     leaf fraction: 37.91 %
# Spectrum 14deg_plot_15_02_0002: Brightness: 56.48 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_15_02_0003 (2): Brightness: 54.04 %
#     soil fraction: 27.93 %
#     leaf fraction: 72.07 %
# Spectrum 14deg_plot_15_02_0003: Brightness: 71.92 %
#     soil fraction: 22.92 %
#     leaf fraction: 77.08 %
# Spectrum 14deg_plot_15_02_0004 (2): Brightness: 60.05 %
#     soil fraction: 15.04 %
#     leaf fraction: 84.96 %
# Spectrum 14deg_plot_15_02_0004: Brightness: 84.05 %
#     soil fraction: 84.4 %
#     leaf fraction: 15.6 %
# Spectrum 14deg_plot_15_02_0005 (2): Brightness: 58.42 %
#     soil fraction: 19.03 %
#     leaf fraction: 80.97 %
# Spectrum 14deg_plot_15_02_0005: Brightness: 65.13 %
#     soil fraction: 11.77 %
#     leaf fraction: 88.23 %
# Spectrum 14deg_plot_15_03_0000: Brightness: 75.94 %
#     soil fraction: 34.32 %
#     leaf fraction: 65.68 %
# Spectrum 14deg_plot_15_03_0001: Brightness: 73.18 %
#     soil fraction: 37.71 %
#     leaf fraction: 62.29 %
# Spectrum 14deg_plot_15_03_0002: Brightness: 100.25 %
#     soil fraction: 34.58 %
#     leaf fraction: 65.42 %
# Spectrum 14deg_plot_15_03_0003: Brightness: 99.46 %
#     soil fraction: 36.24 %
#     leaf fraction: 63.76 %
# Spectrum 14deg_plot_15_03_0004: Brightness: 86.51 %
#     soil fraction: 39.09 %
#     leaf fraction: 60.91 %
# Spectrum 14deg_plot_15_04_0000 (2): Brightness: 87.37 %
#     soil fraction: 29.21 %
#     leaf fraction: 70.79 %
# Spectrum 14deg_plot_15_04_0000: Brightness: 116.24 %
#     soil fraction: 44.19 %
#     leaf fraction: 55.81 %
# Spectrum 14deg_plot_15_04_0001 (2): Brightness: 94.58 %
#     soil fraction: 19.26 %
#     leaf fraction: 80.74 %
# Spectrum 14deg_plot_15_04_0001: Brightness: 109.02 %
#     soil fraction: 38.86 %
#     leaf fraction: 61.14 %
# Spectrum 14deg_plot_15_04_0002 (2): Brightness: 92.1 %
#     soil fraction: 15.84 %
#     leaf fraction: 84.16 %
# Spectrum 14deg_plot_15_04_0002: Brightness: 113.4 %
#     soil fraction: 8.51 %
#     leaf fraction: 91.49 %
# Spectrum 14deg_plot_15_04_0003 (2): Brightness: 96.41 %
#     soil fraction: 26.42 %
#     leaf fraction: 73.58 %
# Spectrum 14deg_plot_15_04_0003: Brightness: 131.15 %
#     soil fraction: 25.93 %
#     leaf fraction: 74.07 %
# Spectrum 14deg_plot_15_04_0004 (2): Brightness: 82.42 %
#     soil fraction: 19.25 %
#     leaf fraction: 80.75 %
# Spectrum 14deg_plot_15_04_0004: Brightness: 113.35 %
#     soil fraction: 11.18 %
#     leaf fraction: 88.82 %
# Spectrum 14deg_plot_15_05_0000: Brightness: 56.46 %
#     soil fraction: 27.15 %
#     leaf fraction: 72.85 %
# Spectrum 14deg_plot_15_05_0001: Brightness: 65.41 %
#     soil fraction: 20.16 %
#     leaf fraction: 79.84 %
# Spectrum 14deg_plot_15_05_0002: Brightness: 84.67 %
#     soil fraction: 18.29 %
#     leaf fraction: 81.71 %
# Spectrum 14deg_plot_15_05_0003: Brightness: 72.36 %
#     soil fraction: 16.79 %
#     leaf fraction: 83.21 %
# Spectrum 14deg_plot_15_05_0004: Brightness: 59.44 %
#     soil fraction: 34.75 %
#     leaf fraction: 65.25 %
# Spectrum 14deg_plot_15_06_0000: Brightness: 61.8 %
#     soil fraction: 24.66 %
#     leaf fraction: 75.34 %
# Spectrum 14deg_plot_15_06_0001: Brightness: 58.71 %
#     soil fraction: 40.16 %
#     leaf fraction: 59.84 %
# Spectrum 14deg_plot_15_06_0002: Brightness: 76.37 %
#     soil fraction: 24.91 %
#     leaf fraction: 75.09 %
# Spectrum 14deg_plot_15_06_0003: Brightness: 66.43 %
#     soil fraction: 24.57 %
#     leaf fraction: 75.43 %
# Spectrum 14deg_plot_15_06_0004: Brightness: 54.5 %
#     soil fraction: 23.63 %
#     leaf fraction: 76.37 %
# Spectrum 14deg_plot_15_07_0000: Brightness: 68.88 %
#     soil fraction: 50.34 %
#     leaf fraction: 49.66 %
# Spectrum 14deg_plot_15_07_0001: Brightness: 79.95 %
#     soil fraction: 49.02 %
#     leaf fraction: 50.98 %
# Spectrum 14deg_plot_15_07_0002: Brightness: 106.25 %
#     soil fraction: 73.95 %
#     leaf fraction: 26.05 %
# Spectrum 14deg_plot_15_07_0003: Brightness: 85.3 %
#     soil fraction: 65.21 %
#     leaf fraction: 34.79 %
# Spectrum 14deg_plot_15_07_0004: Brightness: 84.06 %
#     soil fraction: 61.43 %
#     leaf fraction: 38.57 %
# Spectrum 14deg_plot_15_07_0005: Brightness: 105.25 %
#     soil fraction: 34.08 %
#     leaf fraction: 65.92 %
# Spectrum 14deg_plot_15_07_0006: Brightness: 111.21 %
#     soil fraction: 52.76 %
#     leaf fraction: 47.24 %
# Spectrum 14deg_plot_15_07_0007: Brightness: 90.78 %
#     soil fraction: 46.83 %
#     leaf fraction: 53.17 %
# Spectrum 14deg_plot_15_07_0008: Brightness: 99.75 %
#     soil fraction: 47.17 %
#     leaf fraction: 52.83 %
# Spectrum 14deg_plot_15_08_0000 (2): Brightness: 78.39 %
#     soil fraction: 33.43 %
#     leaf fraction: 66.57 %
# Spectrum 14deg_plot_15_08_0000: Brightness: 103.94 %
#     soil fraction: 21.36 %
#     leaf fraction: 78.64 %
# Spectrum 14deg_plot_15_08_0001 (2): Brightness: 68.42 %
#     soil fraction: 20.1 %
#     leaf fraction: 79.9 %
# Spectrum 14deg_plot_15_08_0001: Brightness: 151.62 %
#     soil fraction: 15.05 %
#     leaf fraction: 84.95 %
# Spectrum 14deg_plot_15_08_0002 (2): Brightness: 79.3 %
#     soil fraction: 40.05 %
#     leaf fraction: 59.95 %
# Spectrum 14deg_plot_15_08_0002: Brightness: 130.35 %
#     soil fraction: 34.46 %
#     leaf fraction: 65.54 %
# Spectrum 14deg_plot_15_08_0003 (2): Brightness: 66.37 %
#     soil fraction: 27.56 %
#     leaf fraction: 72.44 %
# Spectrum 14deg_plot_15_08_0003: Brightness: 124.05 %
#     soil fraction: 40.91 %
#     leaf fraction: 59.09 %
# Spectrum 14deg_plot_15_08_0004 (2): Brightness: 66.61 %
#     soil fraction: 16.49 %
#     leaf fraction: 83.51 %
# Spectrum 14deg_plot_15_08_0004: Brightness: 132.15 %
#     soil fraction: 21.62 %
#     leaf fraction: 78.38 %
# Spectrum 14deg_plot_15_10_0000: Brightness: 67.87 %
#     soil fraction: 36.17 %
#     leaf fraction: 63.83 %
# Spectrum 14deg_plot_15_10_0001: Brightness: 71.49 %
#     soil fraction: 38.33 %
#     leaf fraction: 61.67 %
# Spectrum 14deg_plot_15_10_0002: Brightness: 76.17 %
#     soil fraction: 39.6 %
#     leaf fraction: 60.4 %
# Spectrum 14deg_plot_15_10_0003: Brightness: 78.69 %
#     soil fraction: 38.6 %
#     leaf fraction: 61.4 %
# Spectrum 14deg_plot_15_10_0004: Brightness: 72.99 %
#     soil fraction: 30.68 %
#     leaf fraction: 69.32 %
# Spectrum 14deg_plot_16_01_0000 (2): Brightness: 94.85 %
#     soil fraction: 11.54 %
#     leaf fraction: 88.46 %
# Spectrum 14deg_plot_16_01_0000: Brightness: 44.79 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_01_0001 (2): Brightness: 85.27 %
#     soil fraction: 42.44 %
#     leaf fraction: 57.56 %
# Spectrum 14deg_plot_16_01_0001: Brightness: 51.43 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_01_0002 (2): Brightness: 83.54 %
#     soil fraction: 35.35 %
#     leaf fraction: 64.65 %
# Spectrum 14deg_plot_16_01_0002: Brightness: 46.2 %
#     soil fraction: 20.23 %
#     leaf fraction: 79.77 %
# Spectrum 14deg_plot_16_01_0003 (2): Brightness: 40.81 %
#     soil fraction: 9.18 %
#     leaf fraction: 90.82 %
# Spectrum 14deg_plot_16_01_0003: Brightness: 46.4 %
#     soil fraction: 9.38 %
#     leaf fraction: 90.62 %
# Spectrum 14deg_plot_16_01_0004 (2): Brightness: 80.7 %
#     soil fraction: 9.1 %
#     leaf fraction: 90.9 %
# Spectrum 14deg_plot_16_01_0004: Brightness: 55.84 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_02_0000 (2): Brightness: 134.38 %
#     soil fraction: 20.75 %
#     leaf fraction: 79.25 %
# Spectrum 14deg_plot_16_02_0000: Brightness: 54.16 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_02_0001 (2): Brightness: 133.34 %
#     soil fraction: 26.78 %
#     leaf fraction: 73.22 %
# Spectrum 14deg_plot_16_02_0001: Brightness: 74.9 %
#     soil fraction: 41.41 %
#     leaf fraction: 58.59 %
# Spectrum 14deg_plot_16_02_0002 (2): Brightness: 145.78 %
#     soil fraction: 33.75 %
#     leaf fraction: 66.25 %
# Spectrum 14deg_plot_16_02_0002: Brightness: 61.47 %
#     soil fraction: 30.64 %
#     leaf fraction: 69.36 %
# Spectrum 14deg_plot_16_02_0003 (2): Brightness: 151.17 %
#     soil fraction: 37.11 %
#     leaf fraction: 62.89 %
# Spectrum 14deg_plot_16_02_0003: Brightness: 71.26 %
#     soil fraction: 48.12 %
#     leaf fraction: 51.88 %
# Spectrum 14deg_plot_16_02_0004 (2): Brightness: 132.45 %
#     soil fraction: 24.51 %
#     leaf fraction: 75.49 %
# Spectrum 14deg_plot_16_02_0004: Brightness: 77.25 %
#     soil fraction: 42.86 %
#     leaf fraction: 57.14 %
# Spectrum 14deg_plot_16_03_0000: Brightness: 157.16 %
#     soil fraction: 96.38 %
#     leaf fraction: 3.62 %
# Spectrum 14deg_plot_16_03_0001: Brightness: 161.84 %
#     soil fraction: 100.0 %
#     leaf fraction: 0.0 %
# Spectrum 14deg_plot_16_03_0002: Brightness: 170.03 %
#     soil fraction: 100.0 %
#     leaf fraction: 0.0 %
# Spectrum 14deg_plot_16_03_0003: Brightness: 165.28 %
#     soil fraction: 100.0 %
#     leaf fraction: 0.0 %
# Spectrum 14deg_plot_16_03_0004: Brightness: 140.91 %
#     soil fraction: 100.0 %
#     leaf fraction: 0.0 %
# Spectrum 14deg_plot_16_04_0000: Brightness: 121.24 %
#     soil fraction: 27.94 %
#     leaf fraction: 72.06 %
# Spectrum 14deg_plot_16_04_0001: Brightness: 140.42 %
#     soil fraction: 49.8 %
#     leaf fraction: 50.2 %
# Spectrum 14deg_plot_16_04_0002: Brightness: 175.42 %
#     soil fraction: 35.03 %
#     leaf fraction: 64.97 %
# Spectrum 14deg_plot_16_04_0003: Brightness: 156.25 %
#     soil fraction: 43.73 %
#     leaf fraction: 56.27 %
# Spectrum 14deg_plot_16_04_0004: Brightness: 147.2 %
#     soil fraction: 36.97 %
#     leaf fraction: 63.03 %
# Spectrum 14deg_plot_16_05_0000: Brightness: 81.69 %
#     soil fraction: 23.51 %
#     leaf fraction: 76.49 %
# Spectrum 14deg_plot_16_05_0001: Brightness: 81.56 %
#     soil fraction: 46.34 %
#     leaf fraction: 53.66 %
# Spectrum 14deg_plot_16_05_0002: Brightness: 86.73 %
#     soil fraction: 39.59 %
#     leaf fraction: 60.41 %
# Spectrum 14deg_plot_16_05_0003: Brightness: 86.21 %
#     soil fraction: 36.07 %
#     leaf fraction: 63.93 %
# Spectrum 14deg_plot_16_05_0004: Brightness: 106.37 %
#     soil fraction: 54.12 %
#     leaf fraction: 45.88 %
# Spectrum 14deg_plot_16_06_0000 (2): Brightness: 143.04 %
#     soil fraction: 18.35 %
#     leaf fraction: 81.65 %
# Spectrum 14deg_plot_16_06_0000: Brightness: 69.11 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0001 (2): Brightness: 135.5 %
#     soil fraction: 3.61 %
#     leaf fraction: 96.39 %
# Spectrum 14deg_plot_16_06_0001: Brightness: 69.15 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0002 (2): Brightness: 132.36 %
#     soil fraction: 5.4 %
#     leaf fraction: 94.6 %
# Spectrum 14deg_plot_16_06_0002: Brightness: 65.87 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0003 (2): Brightness: 85.39 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0003: Brightness: 70.81 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0004 (2): Brightness: 88.05 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_16_06_0004: Brightness: 71.24 %
#     soil fraction: 6.22 %
#     leaf fraction: 93.78 %
# Spectrum 14deg_plot_16_07_0000: Brightness: 173.1 %
#     soil fraction: 87.24 %
#     leaf fraction: 12.76 %
# Spectrum 14deg_plot_16_07_0001: Brightness: 102.42 %
#     soil fraction: 64.12 %
#     leaf fraction: 35.88 %
# Spectrum 14deg_plot_16_07_0002: Brightness: 104.18 %
#     soil fraction: 62.73 %
#     leaf fraction: 37.27 %
# Spectrum 14deg_plot_16_07_0003: Brightness: 135.44 %
#     soil fraction: 83.78 %
#     leaf fraction: 16.22 %
# Spectrum 14deg_plot_16_07_0004: Brightness: 82.84 %
#     soil fraction: 67.49 %
#     leaf fraction: 32.51 %
# Spectrum 14deg_plot_16_08_0000: Brightness: 122.52 %
#     soil fraction: 71.23 %
#     leaf fraction: 28.77 %
# Spectrum 14deg_plot_16_08_0001: Brightness: 79.03 %
#     soil fraction: 56.44 %
#     leaf fraction: 43.56 %
# Spectrum 14deg_plot_16_08_0002: Brightness: 98.67 %
#     soil fraction: 53.48 %
#     leaf fraction: 46.52 %
# Spectrum 14deg_plot_16_08_0003: Brightness: 120.61 %
#     soil fraction: 62.1 %
#     leaf fraction: 37.9 %
# Spectrum 14deg_plot_16_08_0004: Brightness: 125.24 %
#     soil fraction: 67.65 %
#     leaf fraction: 32.35 %
# Spectrum 14deg_plot_16_09_0000: Brightness: 76.63 %
#     soil fraction: 35.74 %
#     leaf fraction: 64.26 %
# Spectrum 14deg_plot_16_09_0001: Brightness: 67.19 %
#     soil fraction: 27.78 %
#     leaf fraction: 72.22 %
# Spectrum 14deg_plot_16_09_0002: Brightness: 117.71 %
#     soil fraction: 41.7 %
#     leaf fraction: 58.3 %
# Spectrum 14deg_plot_16_09_0003: Brightness: 132.43 %
#     soil fraction: 51.79 %
#     leaf fraction: 48.21 %
# Spectrum 14deg_plot_16_09_0004: Brightness: 91.17 %
#     soil fraction: 48.74 %
#     leaf fraction: 51.26 %
# Spectrum 14deg_plot_16_10_0000: Brightness: 64.71 %
#     soil fraction: 30.39 %
#     leaf fraction: 69.61 %
# Spectrum 14deg_plot_16_10_0001: Brightness: 84.57 %
#     soil fraction: 35.12 %
#     leaf fraction: 64.88 %
# Spectrum 14deg_plot_16_10_0002: Brightness: 86.81 %
#     soil fraction: 32.63 %
#     leaf fraction: 67.37 %
# Spectrum 14deg_plot_16_10_0003: Brightness: 89.54 %
#     soil fraction: 34.58 %
#     leaf fraction: 65.42 %
# Spectrum 14deg_plot_16_10_0004: Brightness: 88.98 %
#     soil fraction: 40.69 %
#     leaf fraction: 59.31 %
# Spectrum 14deg_plot_17_01_0000 (2): Brightness: 37.15 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_01_0000: Brightness: 63.79 %
#     soil fraction: 36.56 %
#     leaf fraction: 63.44 %
# Spectrum 14deg_plot_17_01_0001 (2): Brightness: 41.74 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_01_0001: Brightness: 70.64 %
#     soil fraction: 39.72 %
#     leaf fraction: 60.28 %
# Spectrum 14deg_plot_17_01_0002 (2): Brightness: 79.09 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_01_0002: Brightness: 77.55 %
#     soil fraction: 33.31 %
#     leaf fraction: 66.69 %
# Spectrum 14deg_plot_17_01_0003 (2): Brightness: 68.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_01_0003: Brightness: 73.19 %
#     soil fraction: 24.13 %
#     leaf fraction: 75.87 %
# Spectrum 14deg_plot_17_01_0004 (2): Brightness: 78.39 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_01_0004: Brightness: 76.61 %
#     soil fraction: 21.18 %
#     leaf fraction: 78.82 %
# Spectrum 14deg_plot_17_02_0000: Brightness: 78.92 %
#     soil fraction: 16.29 %
#     leaf fraction: 83.71 %
# Spectrum 14deg_plot_17_02_0001: Brightness: 101.18 %
#     soil fraction: 44.83 %
#     leaf fraction: 55.17 %
# Spectrum 14deg_plot_17_02_0002: Brightness: 109.9 %
#     soil fraction: 42.76 %
#     leaf fraction: 57.24 %
# Spectrum 14deg_plot_17_02_0003: Brightness: 100.91 %
#     soil fraction: 32.69 %
#     leaf fraction: 67.31 %
# Spectrum 14deg_plot_17_02_0004: Brightness: 93.2 %
#     soil fraction: 22.37 %
#     leaf fraction: 77.63 %
# Spectrum 14deg_plot_17_03_0000: Brightness: 51.74 %
#     soil fraction: 0.33 %
#     leaf fraction: 99.67 %
# Spectrum 14deg_plot_17_03_0001: Brightness: 46.31 %
#     soil fraction: 16.27 %
#     leaf fraction: 83.73 %
# Spectrum 14deg_plot_17_03_0002: Brightness: 54.57 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_03_0003: Brightness: 41.55 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_03_0004: Brightness: 40.56 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0000 (2): Brightness: 52.98 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0000: Brightness: 60.39 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0001 (2): Brightness: 52.36 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0001: Brightness: 66.24 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0002 (2): Brightness: 50.31 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0002: Brightness: 64.34 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0003 (2): Brightness: 60.5 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0003: Brightness: 66.24 %
#     soil fraction: 0.21 %
#     leaf fraction: 99.79 %
# Spectrum 14deg_plot_17_04_0004 (2): Brightness: 60.06 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_04_0004: Brightness: 63.94 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_05_0000: Brightness: 55.21 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_05_0001: Brightness: 59.66 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_05_0002: Brightness: 58.52 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_05_0003: Brightness: 58.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_05_0004: Brightness: 60.78 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0000 (2): Brightness: 62.83 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0000: Brightness: 91.71 %
#     soil fraction: 37.6 %
#     leaf fraction: 62.4 %
# Spectrum 14deg_plot_17_06_0001 (2): Brightness: 58.54 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0001: Brightness: 84.96 %
#     soil fraction: 38.88 %
#     leaf fraction: 61.12 %
# Spectrum 14deg_plot_17_06_0002 (2): Brightness: 60.11 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0002: Brightness: 91.16 %
#     soil fraction: 56.25 %
#     leaf fraction: 43.75 %
# Spectrum 14deg_plot_17_06_0003 (2): Brightness: 64.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0003: Brightness: 92.65 %
#     soil fraction: 45.62 %
#     leaf fraction: 54.38 %
# Spectrum 14deg_plot_17_06_0004 (2): Brightness: 63.86 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_06_0004: Brightness: 94.65 %
#     soil fraction: 61.55 %
#     leaf fraction: 38.45 %
# Spectrum 14deg_plot_17_06_0005: Brightness: 81.52 %
#     soil fraction: 25.26 %
#     leaf fraction: 74.74 %
# Spectrum 14deg_plot_17_07_0000 (2): Brightness: 69.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0000: Brightness: 59.97 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0001 (2): Brightness: 70.45 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0001: Brightness: 72.33 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0002 (2): Brightness: 72.72 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0002: Brightness: 58.94 %
#     soil fraction: 0.19 %
#     leaf fraction: 99.81 %
# Spectrum 14deg_plot_17_07_0003 (2): Brightness: 69.79 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0003: Brightness: 63.56 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0004 (2): Brightness: 71.76 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_07_0004: Brightness: 54.45 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_08_0000: Brightness: 60.12 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_08_0001: Brightness: 60.56 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_08_0002: Brightness: 57.19 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_08_0003: Brightness: 60.06 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_08_0004: Brightness: 57.87 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_09_0000: Brightness: 65.89 %
#     soil fraction: 11.38 %
#     leaf fraction: 88.62 %
# Spectrum 14deg_plot_17_09_0001: Brightness: 63.98 %
#     soil fraction: 12.85 %
#     leaf fraction: 87.15 %
# Spectrum 14deg_plot_17_09_0002: Brightness: 68.78 %
#     soil fraction: 2.77 %
#     leaf fraction: 97.23 %
# Spectrum 14deg_plot_17_09_0003: Brightness: 71.41 %
#     soil fraction: 7.38 %
#     leaf fraction: 92.62 %
# Spectrum 14deg_plot_17_09_0004: Brightness: 67.85 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_10_0000: Brightness: 66.78 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_10_0001: Brightness: 68.36 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_10_0002: Brightness: 71.43 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_10_0003: Brightness: 65.28 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_17_10_0004: Brightness: 62.53 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_07_0000: Brightness: 43.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_07_0001: Brightness: 39.53 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_07_0002: Brightness: 41.02 %
#     soil fraction: 3.98 %
#     leaf fraction: 96.02 %
# Spectrum 14deg_plot_18_07_0003: Brightness: 44.18 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_07_0004: Brightness: 62.98 %
#     soil fraction: 27.27 %
#     leaf fraction: 72.73 %
# Spectrum 14deg_plot_18_10_0000: Brightness: 63.84 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_10_0001: Brightness: 48.67 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_10_0002: Brightness: 59.19 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_10_0003: Brightness: 59.63 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# Spectrum 14deg_plot_18_10_0004: Brightness: 63.75 %
#     soil fraction: 0.0 %
#     leaf fraction: 100.0 %
# "unmixing_results.csv"

# %%
# Prepare storage for CSV export
spectrum_names = String[]
brightness_all = Float64[]
soil_frac_all  = Float64[]
leaf_frac_all  = Float64[]


good_mask = endmember_library.good_bands
class_keys = endmember_library.class_valid_keys

for i in 1:size(mixed_rfl,1)
    spectrum_vec = vec(mixed_rfl[i, good_mask])

    mr, mv, cfr, cfv = unmix_pixel(
        endmember_library,
        spectrum_vec,
        nothing,          # no mask
        class_idx,
        options,
        mode,
        n_mc,
        num_endmembers,
        normalization,
        optimization,
        max_combinations,
        combination_type
    )

    # Extract brightness (last element of mr)
    brightness = mr[end]

    # Map class → fraction
    fractions = Dict(class_keys[j] => mr[j] for j in 1:length(class_keys))
    soil_frac = get(fractions, "soil", NaN)
    leaf_frac = get(fractions, "leaf", NaN)

    # Store for export
    push!(spectrum_names, mixed_names[i])
    push!(brightness_all, brightness)
    push!(soil_frac_all, soil_frac)
    push!(leaf_frac_all, leaf_frac)

    # Console output (optional)
    println("Spectrum $(mixed_names[i]): Brightness $(round(brightness*100,digits=2))%")
    for (class, fraction) in zip(class_keys, mr[1:end-1])
        println("  $class fraction: $(round(fraction*100,digits=2))%")
    end
end

# Create DataFrame and write CSV
results_df = DataFrame(
    spectrum_name = spectrum_names,
    brightness    = brightness_all,
    soil_fraction = soil_frac_all,
    leaf_fraction = leaf_frac_all
)

CSV.write("unmixing_results.csv", results_df)
println("Results exported to unmixing_results.csv")
# Out:
# Spectrum 14deg_plot_11_01_0000: Brightness 79.25%
#   soil fraction: 38.31%
#   leaf fraction: 61.69%
# Spectrum 14deg_plot_11_01_0001: Brightness 72.58%
#   soil fraction: 27.78%
#   leaf fraction: 72.22%
# Spectrum 14deg_plot_11_01_0002: Brightness 79.84%
#   soil fraction: 22.8%
#   leaf fraction: 77.2%
# Spectrum 14deg_plot_11_01_0003: Brightness 74.22%
#   soil fraction: 22.49%
#   leaf fraction: 77.51%
# Spectrum 14deg_plot_11_01_0004: Brightness 69.75%
#   soil fraction: 9.73%
#   leaf fraction: 90.27%
# Spectrum 14deg_plot_11_02_0000: Brightness 68.39%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_02_0001: Brightness 74.78%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_02_0002: Brightness 69.05%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_02_0003: Brightness 56.8%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_03_0000 (2): Brightness 58.93%
#   soil fraction: 10.05%
#   leaf fraction: 89.95%
# Spectrum 14deg_plot_11_03_0000: Brightness 101.58%
#   soil fraction: 35.01%
#   leaf fraction: 64.99%
# Spectrum 14deg_plot_11_03_0001 (2): Brightness 52.41%
#   soil fraction: 5.69%
#   leaf fraction: 94.31%
# Spectrum 14deg_plot_11_03_0001: Brightness 89.83%
#   soil fraction: 39.74%
#   leaf fraction: 60.26%
# Spectrum 14deg_plot_11_03_0002 (2): Brightness 66.17%
#   soil fraction: 6.5%
#   leaf fraction: 93.5%
# Spectrum 14deg_plot_11_03_0002: Brightness 77.97%
#   soil fraction: 25.71%
#   leaf fraction: 74.29%
# Spectrum 14deg_plot_11_03_0003 (2): Brightness 54.8%
#   soil fraction: 14.65%
#   leaf fraction: 85.35%
# Spectrum 14deg_plot_11_03_0003: Brightness 92.57%
#   soil fraction: 27.93%
#   leaf fraction: 72.07%
# Spectrum 14deg_plot_11_03_0004 (2): Brightness 68.15%
#   soil fraction: 25.68%
#   leaf fraction: 74.32%
# Spectrum 14deg_plot_11_03_0004: Brightness 81.88%
#   soil fraction: 40.08%
#   leaf fraction: 59.92%
# Spectrum 14deg_plot_11_04_0000: Brightness 106.19%
#   soil fraction: 39.58%
#   leaf fraction: 60.42%
# Spectrum 14deg_plot_11_04_0001: Brightness 107.22%
#   soil fraction: 40.02%
#   leaf fraction: 59.98%
# Spectrum 14deg_plot_11_04_0002: Brightness 94.67%
#   soil fraction: 19.32%
#   leaf fraction: 80.68%
# Spectrum 14deg_plot_11_04_0003: Brightness 87.36%
#   soil fraction: 46.07%
#   leaf fraction: 53.93%
# Spectrum 14deg_plot_11_04_0004: Brightness 97.18%
#   soil fraction: 37.95%
#   leaf fraction: 62.05%
# Spectrum 14deg_plot_11_05_0000: Brightness 61.74%
#   soil fraction: 10.18%
#   leaf fraction: 89.82%
# Spectrum 14deg_plot_11_05_0001: Brightness 85.54%
#   soil fraction: 28.4%
#   leaf fraction: 71.6%
# Spectrum 14deg_plot_11_05_0002: Brightness 58.99%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_05_0003: Brightness 43.71%
#   soil fraction: 16.23%
#   leaf fraction: 83.77%
# Spectrum 14deg_plot_11_05_0004: Brightness 46.06%
#   soil fraction: 19.39%
#   leaf fraction: 80.61%
# Spectrum 14deg_plot_11_06_0000: Brightness 65.04%
#   soil fraction: 21.87%
#   leaf fraction: 78.13%
# Spectrum 14deg_plot_11_06_0001: Brightness 46.43%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_06_0002: Brightness 40.0%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_06_0003: Brightness 46.84%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_06_0004: Brightness 43.97%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_07_0000: Brightness 61.54%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_07_0001: Brightness 50.12%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_07_0002: Brightness 49.71%
#   soil fraction: 5.48%
#   leaf fraction: 94.52%
# Spectrum 14deg_plot_11_07_0003: Brightness 55.44%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_07_0004: Brightness 54.31%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0000 (2): Brightness 48.99%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0000: Brightness 59.56%
#   soil fraction: 24.87%
#   leaf fraction: 75.13%
# Spectrum 14deg_plot_11_08_0001 (2): Brightness 49.04%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0001: Brightness 78.09%
#   soil fraction: 14.0%
#   leaf fraction: 86.0%
# Spectrum 14deg_plot_11_08_0002 (2): Brightness 49.87%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0002: Brightness 71.52%
#   soil fraction: 19.94%
#   leaf fraction: 80.06%
# Spectrum 14deg_plot_11_08_0003 (2): Brightness 50.14%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0003: Brightness 64.45%
#   soil fraction: 8.12%
#   leaf fraction: 91.88%
# Spectrum 14deg_plot_11_08_0004 (2): Brightness 44.29%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_08_0004: Brightness 69.27%
#   soil fraction: 10.58%
#   leaf fraction: 89.42%
# Spectrum 14deg_plot_11_09_0000: Brightness 45.54%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_09_0001: Brightness 50.93%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_09_0002: Brightness 39.27%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_09_0003: Brightness 40.35%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_09_0004: Brightness 44.07%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_10_0000: Brightness 67.52%
#   soil fraction: 0.0%
#   leaf fraction: 100.0%
# Spectrum 14deg_plot_11_10_0001: Brightness 78.31%
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:1128
#   [2] wait()
#     @ Base .\task.jl:1200
#   [3] uv_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1081
#   [4] unsafe_write(s::Base.PipeEndpoint, p::Ptr{UInt8}, n::UInt64)
#     @ Base .\stream.jl:1154
#   [5] unsafe_write
#     @ .\io.jl:452 [inlined]
#   [6] write
#     @ .\strings\io.jl:246 [inlined]
#   [7] print
#     @ .\strings\io.jl:248 [inlined]
#   [8] print(::IJulia.IJuliaStdio{Base.PipeEndpoint}, ::String, ::String)
#     @ Base .\strings\io.jl:46
#   [9] println(x::String)
#     @ Base .\coreio.jl:5
#  [10] top-level scope
#     @ In[13]:44
#  [11] eval(m::Module, e::Any)
#     @ Core .\boot.jl:489
